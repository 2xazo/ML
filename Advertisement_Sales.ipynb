# %% [markdown]
# <a href="https://colab.research.google.com/github/2xazo/ML/blob/main/Advertisement_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('advertising.csv') # 4

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df['TV']

# %%
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=100)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
#### tgrbh
tvprice=[[111]]
tvp=model.predict(tvprice)  ##### mhm
print(f'tv new price is {tvp}')
# Out:
# tv new price is [13.00124149]

# %%
y_pred=model.predict(x_test.values.reshape(-1,1))

# %%
y_pred
# Out:
# array([ 7.41755568, 19.88345888, 14.31059417, 18.77429648, 20.07282807,
#        18.18454672, 14.5270161 , 17.68677628, 18.70395936, 18.72560155,
#        13.33669548, 19.41274118, 10.03626104, 17.15654255, 11.713531  ,
#        12.09226938, 15.09512366, 16.20428606, 15.84177932, 13.1040419 ,
#        18.61198003, 13.99678237, 17.56774422, 16.57220334, 16.99963665,
#        18.91497074, 18.887918  , 11.06967576, 16.99963665, 13.65591783,
#        10.69634793, 10.72881122, 13.54229631, 17.18900584,  9.70080705,
#        13.51524357, 12.25458583, 16.10689619, 19.02859225, 17.44871216])

# %%
df1 = pd.DataFrame({'actual': y_test, 'predicted': y_pred})

# %%
df1
# Out:
#      actual  predicted
# 126     6.6   7.417556
# 104    20.7  19.883459
# 99     17.2  14.310594
# 92     19.4  18.774296
# 111    21.8  20.072828
# 167    17.2  18.184547
# 116    12.2  14.527016
# 96     16.7  17.686776
# 52     22.6  18.703959
# 69     22.3  18.725602
# 164    11.9  13.336695
# 124    19.7  19.412741
# 182     8.7  10.036261
# 154    20.6  17.156543
# 125    10.6  11.713531
# 196    14.0  12.092269
# 194    17.3  15.095124
# 177    16.7  16.204286
# 163    18.0  15.841779
# 31     11.9  13.104042
# 11     17.4  18.611980
# 73     11.0  13.996782
# 15     22.4  17.567744
# 41     17.1  16.572203
# 97     20.5  16.999637
# 128    24.7  18.914971
# 133    19.6  18.887918
# 82     11.3  11.069676
# 139    20.7  16.999637
# 123    15.2  13.655918
# 83     13.6  10.696348
# 65     11.3  10.728811
# 151    11.6  13.542296
# 162    19.9  17.189006
# 170     8.4   9.700807
# 77     14.2  13.515244
# 32     13.2  12.254586
# 173    16.7  16.106896
# 174    16.5  19.028592
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 1.905152391298234
# Mean Squared Error: 5.34850349246385

# %%
sns.regplot(x=y_test,y=y_pred)
# Out:
# <Axes: xlabel='Sales'>
