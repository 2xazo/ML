# %%
import sklearn
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df[['TV', 'Radio', 'Newspaper']]
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=15) # focus here

# %%
x_train.shape
# Out:
# (160, 3)

# %%
x_test.shape
# Out:
# (40, 3)

# %%
from sklearn.linear_model import LinearRegression
ll=LinearRegression()
ll.fit(x_train.values,y_train)
# Out:
# LinearRegression()

# %%
x_train.values
# Out:
# array([[239.9,  41.5,  18.5],
#        [220.5,  33.2,  37.9],
#        [ 44.7,  25.8,  20.6],
#        [197.6,  23.3,  14.2],
#        [ 56.2,   5.7,  29.7],
#        [  5.4,  29.9,   9.4],
#        [198.9,  49.4,  60. ],
#        [262.9,   3.5,  19.5],
#        [215.4,  23.6,  57.6],
#        [149.7,  35.6,   6. ],
#        [ 57.5,  32.8,  23.5],
#        [163.3,  31.6,  52.9],
#        [296.4,  36.3, 100.9],
#        [121. ,   8.4,  48.7],
#        [ 39.5,  41.1,   5.8],
#        [168.4,   7.1,  12.8],
#        [112.9,  17.4,  38.6],
#        [213.4,  24.6,  13.1],
#        [248.4,  30.2,  20.3],
#        [ 96.2,  14.8,  38.9],
#        [184.9,  21. ,  22. ],
#        [218.4,  27.7,  53.4],
#        [284.3,  10.6,   6.4],
#        [273.7,  28.9,  59.7],
#        [218.5,   5.4,  27.4],
#        [214.7,  24. ,   4. ],
#        [227.2,  15.8,  49.9],
#        [287.6,  43. ,  71.8],
#        [151.5,  41.3,  58.5],
#        [210.7,  29.5,   9.3],
#        [  8.7,  48.9,  75. ],
# ...

# %%
tyt=[[120,50,60]]
pred=ll.predict(tyt)
print('prdict is : ',pred[0])
# Out:
# prdict is :  16.438991649289978

# %%
yP=ll.predict(x_test.values)
print(yP)
# Out:
# [ 9.48014798  9.74034749  9.578992    7.61412598  8.9161981  18.10349948
#  23.80639906  8.45058944  9.52481395 14.02638709  5.91173779  9.33890342
#  21.63371306 18.5788581  21.3716781  15.41198661 15.90374543 12.37618248
#  20.85725333 24.77805334  8.8089096  23.77526226  9.57401827 18.23968951
#  18.18553619 13.03492642 23.14573163  9.20376162 15.20778442 18.26570686
#   6.28886805 21.79104406  9.8413285  12.11724872 19.19663564 10.32455902
#  11.52696495 13.73223973 22.41892146  7.04160649]

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':yP})
df1
# Out:
#      Actual  Predicted
# 49      9.7   9.480148
# 191    11.9   9.740347
# 12      9.2   9.578992
# 172     7.6   7.614126
# 127    11.9   8.916198
# 40     16.6  18.103499
# 30     21.4  23.806399
# 170     8.4   8.450589
# 138     9.6   9.524814
# 57     13.2  14.026387
# 192     5.9   5.911738
# 72      8.8   9.338903
# 150    16.1  21.633713
# 146    18.2  18.578858
# 58     23.8  21.371678
# 26     15.0  15.411987
# 9      15.6  15.903745
# 115    12.6  12.376182
# 184    17.6  20.857253
# 198    25.5  24.778053
# 117     9.4   8.808910
# 36     25.4  23.775262
# 107    12.0   9.574018
# 113    20.9  18.239690
# 165    16.9  18.185536
# 161    13.3  13.034926
# 147    25.4  23.145732
# 65     11.3   9.203762
# 120    15.5  15.207784
# 21     17.5  18.265707
# 91      7.3   6.288868
# 188    20.9  21.791044
# 136     9.5   9.841329
# 71     12.4  12.117249
# 139    20.7  19.196636
# 2      12.0  10.324559
# 86     12.0  11.526965
# 116    12.2  13.732240
# 93     22.2  22.418921
# ...

# %%
sns.regplot(x=y_test,y=yP,color="green")
# Out:
# <Axes: xlabel='Sales'>

# %%
from sklearn import metrics
print('Mean Absolute Error :',metrics.mean_absolute_error(y_test,yP))
print('Mean Squared Error :',metrics.mean_squared_error(y_test,yP))
# Out:
# Mean Absolute Error : 1.1694394885747703
# Mean Squared Error : 2.7111099053683656
